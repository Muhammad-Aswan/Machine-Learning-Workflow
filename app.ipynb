# %%
pip install streamlit
# Out:
# ...
#   Using cached streamlit-1.23.1-py2.py3-none-any.whl.metadata (7.4 kB)
# ...
#   Using cached altair-5.0.1-py3-none-any.whl.metadata (8.5 kB)
# ...
#   Using cached click-8.1.8-py3-none-any.whl.metadata (2.3 kB)
# ...
#   Using cached rich-13.8.1-py3-none-any.whl.metadata (18 kB)
# ...
#   Using cached tzlocal-4.3.1-py3-none-any.whl.metadata (14 kB)
# ...
#   Using cached gitpython-3.1.51-py3-none-any.whl.metadata (14 kB)
# ...
#   Using cached pydeck-0.8.1b1-py2.py3-none-any.whl.metadata (3.9 kB)
# ...
#   Using cached markdown_it_py-2.2.0-py3-none-any.whl.metadata (6.8 kB)
# ...
#   Using cached pytz_deprecation_shim-0.1.0.post0-py2.py3-none-any.whl.metadata (5.2 kB)
# ...
# Using cached streamlit-1.23.1-py2.py3-none-any.whl (8.9 MB)
# Using cached altair-5.0.1-py3-none-any.whl (471 kB)
# Using cached click-8.1.8-py3-none-any.whl (98 kB)
# Using cached gitpython-3.1.51-py3-none-any.whl (215 kB)
# Using cached pydeck-0.8.1b1-py2.py3-none-any.whl (7.0 MB)
# Using cached rich-13.8.1-py3-none-any.whl (241 kB)
# ...

# %%
# Out:
# 2026-07-16 01:40:54.354
# ...
#   command:
#
#     streamlit run c:\users\aik\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py [ARGUMENTS]

# %%
# Out:
#   File "C:\Users\AiK\AppData\Local\Temp\ipykernel_9836\3737097518.py", line 1
#     streamlit run app.py
#                 ^
# SyntaxError: invalid syntax
